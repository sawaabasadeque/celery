# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/Users/brodyuehara/Downloads/alduin-390505-cc185311f611.json'

# %%
from backtester.engine import BacktestEngine

# Create a Backtester object
start_year_month ='2021-01'
end_year_month ='2021-02'

backtester = BacktestEngine(start_date=start_year_month, end_date=end_year_month, sell_strike_method="desired_premium", portfolio_value=1000000, spread=50)

# Run the backtest
eval_data, unrealized_results = backtester.run()
# Out:
# INFO:root:
#         -----------------------------------------------------------------
#         Initializing backtest between 2021-01 & 2021-02:
#         Selling strike method: desired_premium,
#         Spread: 50,
#         Portfolio Value: 1000000.
#         -----------------------------------------------------------------
#
# INFO:root:Executing trades...
# INFO:root:Successfully queried data for date 2021-01-04 and root SPX
# INFO:root:Using sell strike of 3000.0 using desired_premium method.
# INFO:root:Adding new trade to execution stack on 2021-01-04 with expiration 2021-02-19 w/ last tradeable date 2021-02-28
# ...

# %%
#  underlying_symbol  quote_date root  expiration  strike option_type  open  high   low  close  trade_volume  bid_size_1545  bid_1545  ask_size_1545  ask_1545  underlying_bid_1545  underlying_ask_1545  implied_underlying_price_1545  active_underlying_price_1545  implied_volatility_1545  delta_1545  gamma_1545  theta_1545  vega_1545  rho_1545  bid_size_eod  bid_eod  ask_size_eod  ask_eod  underlying_bid_eod  underlying_ask_eod    vwap  open_interest delivery_code  DTE
# 0              ^SPX  2021-01-04  SPX  2021-02-19  1000.0           P  0.17  0.17  0.16   0.16            12            138      0.05              1      0.20              3699.96              3701.38                            0.0                       3700.67                   1.1309     -0.0003         0.0     -0.0145     0.0126   -0.0013           441     0.10             1     0.20             3700.26             3702.24  0.1667           8323          None   46
# 1              ^SPX  2021-01-04  SPX  2021-02-19  1100.0           P  0.25  0.25  0.25   0.25             1            338      0.10              1      0.30              3699.96              3701.38                            0.0                       3700.67                   1.1186     -0.0006         0.0     -0.0294     0.0257   -0.0028           472     0.15             1     0.30             3700.26             3702.24  0.2500           3530          None   46
# 2              ^SPX  2021-01-04  SPX  2021-02-19  1200.0           P  0.30  0.30  0.30   0.30             2            238      0.20              1      0.35              3699.96              3701.38                            0.0                       3700.67                   1.0498     -0.0007         0.0     -0.0321     0.0299   -0.0032           278     0.25             1     0.35             3700.26             3702.24  0.3000           2454          None   46
# 3              ^SPX  2021-01-04  SPX  2021-02-19  1300.0           P  0.40  0.40  0.40   0.40             2            803      0.25              1      0.45              3699.96              3701.38                            0.0                       3700.67                   1.0125     -0.0010         0.0     -0.0453     0.0436   -0.0048           466     0.30             1     0.45             3700.26             3702.24  0.4000           3243          None   46
# 4              ^SPX  2021-01-04  SPX  2021-02-19  1400.0           P  0.25  0.50  0.25   0.50             5            490      0.40            160      0.55              3699.96              3701.38                            0.0                       3700.67                   0.9640     -0.0013         0.0     -0.0552     0.0558   -0.0063           472     0.40             1     0.55             3700.26             3702.24  0.3800           6441          None   46
